# %%
using JuMP, CSV, DataFrames, Gurobi, Interpolations

# %%
# Read the test and train CSV files
data_targeted = CSV.File("Data_Targeted.csv") |> DataFrame;
data_email = CSV.File("Data_Emails.csv") |> DataFrame;
data_print = CSV.File("Data_Print.csv") |> DataFrame;
data_influencer = CSV.File("Data_Influencers.csv") |> DataFrame;

# %%
B = [400.0, 800.0, 1000.0, 1200.0, 1500.0, 2000.0, 2500.0, 4000.0, 5000.0];

# %%
# Creating linear interpolation functions for each marketing option
interp_targeted = LinearInterpolation(data_targeted[!, :Cost], data_targeted[!, :Views]);
interp_email = LinearInterpolation(data_email[!, :Cost], data_email[!, :Views]);
interp_print = LinearInterpolation(data_print[!, :Cost], data_print[!, :Views]);
interp_influencers = LinearInterpolation(data_influencer[!, :Cost], data_influencer[!, :Views]);

# %% [markdown]
# ## BASELINE

# %% [markdown]
# In summary, linear interpolation is used here to create a continuous function from your discrete data points, allowing the optimization model to work effectively with any investment amount within the provided ranges. It bridges the gap between your data and the needs of the optimization solver.

# %%
for Budget in B
        # Optimization model
        model = Model(Gurobi.Optimizer)
        
        # Decision variables for investments
        @variable(model, investment_targeted >= 0)
        @variable(model, investment_email >= 0)
        @variable(model, investment_print >= 0)
        @variable(model, investment_influencers >= 0)
        
        # Additional variables and constraints for piecewise linear segments for each marketing option
        # Helps in modeling non-linear relationships
        
        # Creating a piecewise linear function
        # Targeted Online Advertising
        @variable(model, targeted_segments[1:3] >= 0) #each col is non-negative
        
        breakpoints_targeted = [0, 40, 310, 990] 
        # Example breakpoints 
        #defines the investment levels at which the slope (rate of increase in views) changes. 
        #These breakpoints divide the investment range into segments.
        
        slopes_targeted = [3, 4, 5] 
        # Example slopes
        # represents the rate of change in views per unit of investment in each segment. For instance, a slope of 0.8 for the 
        #first segment means that for each unit of investment in this segment, the views increase by 0.8.
        
        @constraint(model, investment_targeted == sum(targeted_segments)) #the sum of investments across all segments
        
        @constraint(model, sum(targeted_segments[i] for i in 1:3) <= breakpoints_targeted[end])
        for i in 1:3
            @constraint(model, targeted_segments[i] <= breakpoints_targeted[i+1] - breakpoints_targeted[i])
        end
        
        # Email Marketing - done
        # Example breakpoints and slopes for Email Marketing
        @variable(model, email_segments[1:3] >= 0) 
        breakpoints_email = [0, 77.05, 144.87, 300] # Example breakpoints 
        slopes_email = [18, 19.99, 19.95] # Example slopes
        @constraint(model, investment_email == sum(email_segments))
        @constraint(model, sum(email_segments[i] for i in 1:3) <= breakpoints_email[end])
        for i in 1:3
            @constraint(model, email_segments[i] <= breakpoints_email[i+1] - breakpoints_email[i])
        end
        
        # Print Media - done
        # Example breakpoints and slopes for Print Media
        @variable(model, print_segments[1:3] >= 0)
        slopes_print = [12, 40, 73] # Example breakpoints
        breakpoints_print = [200, 375, 565, 695] # Example slopes
        @constraint(model, investment_print == sum(print_segments))
        @constraint(model, sum(print_segments[i] for i in 1:3) <= breakpoints_print[end])
        for i in 1:3
            @constraint(model, print_segments[i] <= breakpoints_print[i+1] - breakpoints_print[i])
        end
        
        # Influencer Marketing - done
        # Example breakpoints and slopes for Influencer Marketing
        @variable(model, influencers_segments[1:3] >= 0)
        breakpoints_influencers = [100, 298, 406, 694] # Example breakpoints
        slopes_influencers = [10, 6, 2] # Example slopes
        @constraint(model, investment_influencers == sum(influencers_segments))
        @constraint(model, sum(influencers_segments[i] for i in 1:3) <= breakpoints_influencers[end])
        for i in 1:3
            @constraint(model, influencers_segments[i] <= breakpoints_influencers[i+1] - breakpoints_influencers[i])
        end
        
        # Objective: Maximize views
        @objective(model, Max, sum(slopes_targeted[i] * targeted_segments[i] for i in eachindex(slopes_targeted)) + 
                      sum(slopes_email[i] * email_segments[i] for i in eachindex(slopes_email)) +
                      sum(slopes_print[i] * print_segments[i] for i in eachindex(slopes_print)) +
                      sum(slopes_influencers[i] * influencers_segments[i] for i in eachindex(slopes_influencers)))

        
        # Budget constraint
            @constraint(model, investment_targeted + investment_email +
                           investment_print + investment_influencers <= Budget)

        # Baseline constraints
        @constraint(model, investment_targeted <= Budget/4)
        @constraint(model, investment_email <= Budget/4)
        @constraint(model, investment_print <= Budget/4)
        @constraint(model, investment_influencers <= Budget/4)
        
        # Solve the model
        optimize!(model)
        
        # Results
        println("Optimal Investments with Budget = ", Budget)
        println("Targeted Online Advertising: \$", value(investment_targeted))
        println("Email Marketing: \$", value(investment_email))
        println("Print Media: \$", value(investment_print))
        println("Influencer Marketing: \$", value(investment_influencers))
        println("Total Views: ", objective_value(model))
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0xae7f2303
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+03]
# Presolve removed 25 rows and 16 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0797713e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.079771280e+04
#
# User-callback calls 45, time in user-callback 0.00 sec
# Optimal Investments with Budget = 400.0
# Targeted Online Advertising: $100.0
# Email Marketing: $100.0
# Print Media: $100.0
# Influencer Marketing: $100.0
# Total Views: 10797.7128
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x8ae50363
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+03]
# Presolve removed 22 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1598000e+04   2.552250e+01   0.000000e+00      0s
#        3    1.9274713e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.927471280e+04
#
# User-callback calls 59, time in user-callback 0.00 sec
# Optimal Investments with Budget = 800.0
# Targeted Online Advertising: $200.0
# Email Marketing: $200.0
# Print Media: $200.0
# Influencer Marketing: $200.0
# Total Views: 19274.7128
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x24102e8a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+03]
# Presolve removed 22 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6997500e+04   4.427250e+01   0.000000e+00      0s
#        3    2.2769465e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.276946530e+04
#
# User-callback calls 59, time in user-callback 0.00 sec
# Optimal Investments with Budget = 1000.0
# Targeted Online Advertising: $250.0
# Email Marketing: $250.0
# Print Media: $250.0
# Influencer Marketing: $250.0
# Total Views: 22769.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x461d9cb5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+03]
# Presolve removed 23 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 6 columns, 6 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2237465e+04   3.400000e+01   0.000000e+00      0s
#        2    2.6219465e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.621946530e+04
#
# User-callback calls 52, time in user-callback 0.00 sec
# Optimal Investments with Budget = 1200.0
# Targeted Online Advertising: $300.0
# Email Marketing: $300.0
# Print Media: $300.0
# Influencer Marketing: $300.0
# Total Views: 26219.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x7207260a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 2e+03]
# Presolve removed 23 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 6 columns, 6 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8837465e+04   5.275000e+01   0.000000e+00      0s
#        2    2.8228465e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.822846530e+04
#
# User-callback calls 52, time in user-callback 0.00 sec
# Optimal Investments with Budget = 1500.0
# Targeted Online Advertising: $375.0
# Email Marketing: $300.0
# Print Media: $375.0
# Influencer Marketing: $375.0
# Total Views: 28228.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x030f68d3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 2e+03]
# Presolve removed 24 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2527465e+04   3.775000e+01   0.000000e+00      0s
#        1    3.0543465e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.054346530e+04
#
# User-callback calls 48, time in user-callback 0.00 sec
# Optimal Investments with Budget = 2000.0
# Targeted Online Advertising: $500.0
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $500.0
# Total Views: 30543.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x25517fa4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 2e+03]
# Presolve removed 25 rows and 16 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1356465e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.135646530e+04
#
# User-callback calls 45, time in user-callback 0.00 sec
# Optimal Investments with Budget = 2500.0
# Targeted Online Advertising: $625.0
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $594.0
# Total Views: 31356.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x9005ba82
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 4e+03]
# Presolve removed 25 rows and 16 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2831465e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.283146530e+04
#
# User-callback calls 32, time in user-callback 0.00 sec
# Optimal Investments with Budget = 4000.0
# Targeted Online Advertising: $990.0
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $594.0
# Total Views: 32831.465299999996
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x7a64fe30
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 5e+03]
# Presolve removed 25 rows and 16 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2831465e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.283146530e+04
#
# User-callback calls 32, time in user-callback 0.00 sec
# Optimal Investments with Budget = 5000.0
# Targeted Online Advertising: $990.0
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $594.0
# Total Views: 32831.465299999996

# %% [markdown]
# ## MIO

# %%
BigM = 10000
# Out:
# 10000

# %%
for Budget in B
        # Optimization model
        model = Model(Gurobi.Optimizer)
        
       # Decision variables for investments
        @variable(model, investment_targeted >= 0)
        @variable(model, investment_email >= 0)
        @variable(model, investment_print >= 0)
        @variable(model, investment_influencers >= 0)
        
        # Binary variables for onboarding fee
        @variable(model, onboard_targeted, Bin)
        @variable(model, onboard_email, Bin)
        @variable(model, onboard_print, Bin)
        @variable(model, onboard_influencers, Bin)
        
        # Onboarding fee constraints
        @constraint(model, investment_targeted <= onboard_targeted * BigM)
        @constraint(model, investment_email <= onboard_email * BigM)
        @constraint(model, investment_print <= onboard_print * BigM)
        @constraint(model, investment_influencers <= onboard_influencers * BigM)

        # Additional variables and constraints for piecewise linear segments for each marketing option
        # Helps in modeling non-linear relationships
        
        # Creating a piecewise linear function
        # Targeted Online Advertising
        @variable(model, targeted_segments[1:3] >= 0) #each col is non-negative
        
        breakpoints_targeted = [0, 40, 310, 990] 
        # Example breakpoints 
        #defines the investment levels at which the slope (rate of increase in views) changes. 
        #These breakpoints divide the investment range into segments.
        
        slopes_targeted = [3, 4, 5] 
        # Example slopes
        # represents the rate of change in views per unit of investment in each segment. For instance, a slope of 0.8 for the 
        #first segment means that for each unit of investment in this segment, the views increase by 0.8.
        
        @constraint(model, investment_targeted == sum(targeted_segments)) #the sum of investments across all segments
        
        @constraint(model, sum(targeted_segments[i] for i in 1:3) <= breakpoints_targeted[end])
        for i in 1:3
            @constraint(model, targeted_segments[i] <= breakpoints_targeted[i+1] - breakpoints_targeted[i])
        end
        
        # Email Marketing - done
        # Example breakpoints and slopes for Email Marketing
        @variable(model, email_segments[1:3] >= 0) 
        breakpoints_email = [0, 77.05, 144.87, 300] # Example breakpoints 
        slopes_email = [18, 19.99, 19.95] # Example slopes
        @constraint(model, investment_email == sum(email_segments))
        @constraint(model, sum(email_segments[i] for i in 1:3) <= breakpoints_email[end])
        for i in 1:3
            @constraint(model, email_segments[i] <= breakpoints_email[i+1] - breakpoints_email[i])
        end
        
        # Print Media - done
        # Example breakpoints and slopes for Print Media
        @variable(model, print_segments[1:3] >= 0)
        slopes_print = [12, 40, 73] # Example breakpoints
        breakpoints_print = [200, 375, 565, 695] # Example slopes
        @constraint(model, investment_print == sum(print_segments))
        @constraint(model, sum(print_segments[i] for i in 1:3) <= breakpoints_print[end])
        for i in 1:3
            @constraint(model, print_segments[i] <= breakpoints_print[i+1] - breakpoints_print[i])
        end
        
        # Influencer Marketing - done
        # Example breakpoints and slopes for Influencer Marketing
        @variable(model, influencers_segments[1:3] >= 0)
        breakpoints_influencers = [100, 298, 406, 694] # Example breakpoints
        slopes_influencers = [10, 6, 2] # Example slopes
        @constraint(model, investment_influencers == sum(influencers_segments))
        @constraint(model, sum(influencers_segments[i] for i in 1:3) <= breakpoints_influencers[end])
        for i in 1:3
            @constraint(model, influencers_segments[i] <= breakpoints_influencers[i+1] - breakpoints_influencers[i])
        end
        
        # Objective: Maximize views
        @objective(model, Max, sum(slopes_targeted[i] * targeted_segments[i] for i in eachindex(slopes_targeted)) + 
                      sum(slopes_email[i] * email_segments[i] for i in eachindex(slopes_email)) +
                      sum(slopes_print[i] * print_segments[i] for i in eachindex(slopes_print)) +
                      sum(slopes_influencers[i] * influencers_segments[i] for i in eachindex(slopes_influencers)))
    
        # Budget constraint
            @constraint(model, investment_targeted + investment_email +
                           investment_print + investment_influencers + 
            200*(onboard_targeted + onboard_email + onboard_print + onboard_influencers) <= Budget)
        # Solve the model
        optimize!(model)
        
        # Results
        println("Optimal Investments with Budget = ", Budget)
        println("Targeted Online Advertising: \$", value(investment_targeted))
        println("Email Marketing: \$", value(investment_email))
        println("Print Media: \$", value(investment_print))
        println("Influencer Marketing: \$", value(investment_influencers))
        println("Total Views: ", objective_value(model))

        # Check which investments have been made and calculate onboarding fees
        onboarding_fees_paid = 0
        total_investment = 0
        
        # Create a dictionary to map the investment decision variables to their names and binary onboarding variables
        investments = Dict(
            "Targeted Online Advertising" => (investment_targeted, onboard_targeted),
            "Email Marketing" => (investment_email, onboard_email),
            "Print Media" => (investment_print, onboard_print),
            "Influencer Marketing" => (investment_influencers, onboard_influencers)
        )
        
        println("Investments with onboarding fees:")
        for (name, (invest_var, onboard_var)) in investments
            invest_value = value(invest_var)
            onboard_value = value(onboard_var)
            total_investment += invest_value
            if onboard_value == 1
                onboarding_fees_paid += 200
                println("$name: \$", invest_value, " (Onboarding Fee Paid)")
            else
                println("$name: \$", invest_value)
            end
        end
        
        println("Total Onboarding Fees Paid: \$", onboarding_fees_paid)
        println("Total Investment Amount: \$", total_investment)
        println("Total Views: ", objective_value(model))
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 20 columns and 56 nonzeros
# Model fingerprint: 0x7df6bd8f
# Variable types: 16 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 14 columns, 28 nonzeros
# Variable types: 10 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 1.495667e+04, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 14956.6667    0    1   -0.00000 14956.6667      -     -    0s
# H    0     0                    12290.000000 14956.6667  21.7%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 12290 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.229000000000e+04, best bound 1.229000000000e+04, gap 0.0000%
#
# User-callback calls 284, time in user-callback 0.00 sec
# Optimal Investments with Budget = 400.0
# Targeted Online Advertising: $0.0
# Email Marketing: $0.0
# Print Media: $199.99999999999994
# Influencer Marketing: $0.0
# Total Views: 12289.999999999998
# Investments with onboarding fees:
# Print Media: $199.99999999999994 (Onboarding Fee Paid)
# Email Marketing: $0.0
# Influencer Marketing: $0.0
# Targeted Online Advertising: $0.0
# Total Onboarding Fees Paid: $200
# Total Investment Amount: $199.99999999999994
# Total Views: 12289.999999999998
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 20 columns and 56 nonzeros
# Model fingerprint: 0x98c10972
# Variable types: 16 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 16 columns, 32 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 2.129068e+04, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 21290.6764    0    2   -0.00000 21290.6764      -     -    0s
# H    0     0                    16073.706739 21290.6764  32.5%     -    0s
# H    0     0                    18688.712800 21290.6764  13.9%     -    0s
# H    0     0                    19190.000000 20357.3297  6.08%     -    0s
#      0     0 19190.0000    0    1 19190.0000 19190.0000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 2
#   RLT: 1
#
# Explored 1 nodes (7 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 19190 18688.7 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.919000000000e+04, best bound 1.919000000000e+04, gap 0.0000%
#
# User-callback calls 256, time in user-callback 0.00 sec
# Optimal Investments with Budget = 800.0
# Targeted Online Advertising: $0.0
# Email Marketing: $0.0
# Print Media: $495.0
# Influencer Marketing: $0.0
# Total Views: 19190.0
# Investments with onboarding fees:
# Print Media: $495.0 (Onboarding Fee Paid)
# Email Marketing: $0.0
# Influencer Marketing: $0.0
# Targeted Online Advertising: $0.0
# Total Onboarding Fees Paid: $200
# Total Investment Amount: $495.0
# Total Views: 19190.0
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 20 columns and 56 nonzeros
# Model fingerprint: 0x457a03f7
# Variable types: 16 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 16 columns, 32 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 2.336085e+04, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 23360.8466    0    1   -0.00000 23360.8466      -     -    0s
# H    0     0                    21116.242278 23360.8466  10.6%     -    0s
# H    0     0                    22241.350192 23360.8466  5.03%     -    0s
# H    0     0                    22567.465300 22567.4653  0.00%     -    0s
#      0     0          -    0      22567.4653 22567.4653  0.00%     -    0s
#
# Cutting planes:
#   Relax-and-lift: 1
#
# Explored 1 nodes (9 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 22567.5 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.256746530000e+04, best bound 2.256746530000e+04, gap 0.0000%
#
# User-callback calls 253, time in user-callback 0.00 sec
# Optimal Investments with Budget = 1000.0
# Targeted Online Advertising: $0.0
# Email Marketing: $279.99999999999994
# Print Media: $320.0
# Influencer Marketing: $0.0
# Total Views: 22567.4653
# Investments with onboarding fees:
# Print Media: $320.0 (Onboarding Fee Paid)
# Email Marketing: $279.99999999999994 (Onboarding Fee Paid)
# Influencer Marketing: $0.0
# Targeted Online Advertising: $0.0
# Total Onboarding Fees Paid: $400
# Total Investment Amount: $600.0
# Total Views: 22567.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 20 columns and 56 nonzeros
# Model fingerprint: 0xdb2b7b6a
# Variable types: 16 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 16 columns, 32 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 2.506487e+04, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 25064.8708    0    1   -0.00000 25064.8708      -     -    0s
# H    0     0                    17367.465300 25064.8708  44.3%     -    0s
# H    0     0                    25027.465300 25064.8708  0.15%     -    0s
#      0     0 25064.8708    0    1 25027.4653 25064.8708  0.15%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 25027.5 17367.5 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.502746530000e+04, best bound 2.502746530000e+04, gap 0.0000%
#
# User-callback calls 246, time in user-callback 0.00 sec
# Optimal Investments with Budget = 1200.0
# Targeted Online Advertising: $0.0
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $0.0
# Total Views: 25027.4653
# Investments with onboarding fees:
# Print Media: $495.0 (Onboarding Fee Paid)
# Email Marketing: $300.0 (Onboarding Fee Paid)
# Influencer Marketing: $0.0
# Targeted Online Advertising: $0.0
# Total Onboarding Fees Paid: $400
# Total Investment Amount: $795.0
# Total Views: 25027.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 20 columns and 56 nonzeros
# Model fingerprint: 0x51922b3c
# Variable types: 16 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 2e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 16 columns, 32 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 2.718851e+04, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 27188.5081    0    1   -0.00000 27188.5081      -     -    0s
# H    0     0                    25956.770086 27188.5081  4.75%     -    0s
# H    0     0                    26077.465300 27188.5081  4.26%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 1
#   Flow cover: 1
#
# Explored 1 nodes (5 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 26077.5 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.607746530000e+04, best bound 2.607746530000e+04, gap 0.0000%
#
# User-callback calls 250, time in user-callback 0.00 sec
# Optimal Investments with Budget = 1500.0
# Targeted Online Advertising: $0.0
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $105.00000000000014
# Total Views: 26077.4653
# Investments with onboarding fees:
# Print Media: $495.0 (Onboarding Fee Paid)
# Email Marketing: $300.0 (Onboarding Fee Paid)
# Influencer Marketing: $105.00000000000014 (Onboarding Fee Paid)
# Targeted Online Advertising: $0.0
# Total Onboarding Fees Paid: $600
# Total Investment Amount: $900.0000000000001
# Total Views: 26077.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 20 columns and 56 nonzeros
# Model fingerprint: 0x34722661
# Variable types: 16 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 2e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 16 columns, 32 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 2.927175e+04, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 29271.7503    0    2   -0.00000 29271.7503      -     -    0s
# H    0     0                    28150.465300 29271.7503  3.98%     -    0s
# H    0     0                    28231.465300 29271.7503  3.68%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (6 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 28231.5 28150.5 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.823146530000e+04, best bound 2.823146530000e+04, gap 0.0000%
#
# User-callback calls 313, time in user-callback 0.00 sec
# Optimal Investments with Budget = 2000.0
# Targeted Online Advertising: $0.0
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $594.0
# Total Views: 28231.4653
# Investments with onboarding fees:
# Print Media: $495.0 (Onboarding Fee Paid)
# Email Marketing: $300.0 (Onboarding Fee Paid)
# Influencer Marketing: $594.0 (Onboarding Fee Paid)
# Targeted Online Advertising: $0.0
# Total Onboarding Fees Paid: $600
# Total Investment Amount: $1389.0
# Total Views: 28231.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 20 columns and 56 nonzeros
# Model fingerprint: 0x40d8aa61
# Variable types: 16 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 2e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 21 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 15 columns, 27 nonzeros
# Found heuristic solution: objective 5.0000000
# Variable types: 12 continuous, 3 integer (3 binary)
#
# Root relaxation: objective 3.085653e+04, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 30856.5259    0    1    5.00000 30856.5259      -     -    0s
# H    0     0                    30650.465300 30856.5259  0.67%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 30650.5 5 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.065046530000e+04, best bound 3.065046530000e+04, gap 0.0000%
#
# User-callback calls 362, time in user-callback 0.00 sec
# Optimal Investments with Budget = 2500.0
# Targeted Online Advertising: $599.0000000000001
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $306.0
# Total Views: 30650.4653
# Investments with onboarding fees:
# Print Media: $495.0 (Onboarding Fee Paid)
# Email Marketing: $300.0 (Onboarding Fee Paid)
# Influencer Marketing: $306.0 (Onboarding Fee Paid)
# Targeted Online Advertising: $599.0000000000001 (Onboarding Fee Paid)
# Total Onboarding Fees Paid: $800
# Total Investment Amount: $1700.0
# Total Views: 30650.4653
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 20 columns and 56 nonzeros
# Model fingerprint: 0x7355275b
# Variable types: 16 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 4e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 25 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 32831.5 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.283146530000e+04, best bound 3.283146530000e+04, gap 0.0000%
#
# User-callback calls 191, time in user-callback 0.00 sec
# Optimal Investments with Budget = 4000.0
# Targeted Online Advertising: $990.0
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $594.0
# Total Views: 32831.465299999996
# Investments with onboarding fees:
# Print Media: $495.0 (Onboarding Fee Paid)
# Email Marketing: $300.0 (Onboarding Fee Paid)
# Influencer Marketing: $594.0 (Onboarding Fee Paid)
# Targeted Online Advertising: $990.0 (Onboarding Fee Paid)
# Total Onboarding Fees Paid: $800
# Total Investment Amount: $2379.0
# Total Views: 32831.465299999996
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 20 columns and 56 nonzeros
# Model fingerprint: 0x55307718
# Variable types: 16 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 5e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 25 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 32831.5 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.283146530000e+04, best bound 3.283146530000e+04, gap 0.0000%
#
# User-callback calls 191, time in user-callback 0.00 sec
# Optimal Investments with Budget = 5000.0
# Targeted Online Advertising: $990.0
# Email Marketing: $300.0
# Print Media: $495.0
# Influencer Marketing: $594.0
# Total Views: 32831.465299999996
# Investments with onboarding fees:
# Print Media: $495.0 (Onboarding Fee Paid)
# Email Marketing: $300.0 (Onboarding Fee Paid)
# Influencer Marketing: $594.0 (Onboarding Fee Paid)
# Targeted Online Advertising: $990.0 (Onboarding Fee Paid)
# Total Onboarding Fees Paid: $800
# Total Investment Amount: $2379.0
# Total Views: 32831.465299999996
